# %%
from keras.models import load_model
import numpy as np

# %%
m= load_model('facedetectection.h5')

# %%
from keras.preprocessing import image

# %%
testimage= image.load_img('F://faces//test//mohit//162.jpg',target_size=(224,224,3))

# %%
testimage
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x19245BA1A08>

# %%
testimage= image.img_to_array(testimage)

# %%
testimage= np.expand_dims(testimage,axis=0)

# %%
# conferming the shape
testimage.shape
# Out:
# (1, 224, 224, 3)

# %%
m.predict(testimage)
# Out:
# array([[1., 0.]], dtype=float32)

# %%
m.predict(testimage).argmax(axis=-1)
# Out:
# array([0], dtype=int64)

# %%
# dictionary that maps the prediction value to output label
d={0: "mohit",
  1:"rakesh"}

# %%
# we will be needing the [0] value of from the returned data of argmax

# %%
result=d[m.predict(testimage).argmax(axis=-1)[0]]
result
# Out:
# 'mohit'
